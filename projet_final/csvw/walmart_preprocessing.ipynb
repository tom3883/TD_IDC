# %% [markdown]
# # CSV preprocessing Walmart dataset
#
# Authors : Yana RAGOZINA - Thomas PAUL
#
# The goal of this notebook is to process the csv walmart dataset to reduce its size (rows and columns).
#
# Original dataset is not included to its large size but can be found here : https://www.kaggle.com/datasets/thedevastator/product-prices-and-sizes-from-walmart-grocery?resource=download

# %%
import pandas as pd

# %%
df = pd.read_csv("./WMT_Grocery_202209.csv")

df.head()
# Out:
# /var/folders/vk/y9jgq1cn06390vrymhkpq0kw0000gn/T/ipykernel_37103/725998253.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./WMT_Grocery_202209.csv")
#    index  SHIPPING_LOCATION DEPARTMENT               CATEGORY SUBCATEGORY  \
# 0      0              79936       Deli  Hummus, Dips, & Salsa         NaN
# 1      1              79936       Deli  Hummus, Dips, & Salsa         NaN
# 2      2              79936       Deli  Hummus, Dips, & Salsa         NaN
# 3      3              79936       Deli  Hummus, Dips, & Salsa         NaN
# 4      4              79936       Deli  Hummus, Dips, & Salsa         NaN
#
#                   BREADCRUMBS        SKU  \
# 0  Deli/Hummus, Dips, & Salsa  110895339
# 1  Deli/Hummus, Dips, & Salsa  105455228
# 2  Deli/Hummus, Dips, & Salsa  128642379
# 3  Deli/Hummus, Dips, & Salsa  366126367
# 4  Deli/Hummus, Dips, & Salsa  160090316
#
#                                          PRODUCT_URL  \
# 0  https://www.walmart.com/ip/Marketside-Roasted-...
# 1  https://www.walmart.com/ip/Marketside-Roasted-...
# 2  https://www.walmart.com/ip/Marketside-Classic-...
# 3  https://www.walmart.com/ip/Marketside-Everythi...
# 4  https://www.walmart.com/ip/Price-s-Jalapeno-Di...
#
#                                   PRODUCT_NAME       BRAND  PRICE_RETAIL  \
# 0  Marketside Roasted Red Pepper Hummus, 10 Oz  Marketside          2.67
# 1      Marketside Roasted Garlic Hummus, 10 Oz  Marketside          2.67
# 2             Marketside Classic Hummus, 10 Oz  Marketside          2.67
# 3          Marketside Everything Hummus, 10 oz  Marketside          2.67
# 4                 Price's Jalapeno Dip, 12 Oz.     Price's          3.12
#
#    PRICE_CURRENT PRODUCT_SIZE  PROMOTION              RunDate       tid
# 0           2.67           10        NaN  2022-09-11 21:20:04  16163804
# 1           2.67           10        NaN  2022-09-11 21:20:04  16163805
# 2           2.67           10        NaN  2022-09-11 21:20:04  16163806
# 3           2.67           10        NaN  2022-09-11 21:20:04  16163807
# 4           3.12           12        NaN  2022-09-11 21:20:04  16163808

# %%
# Removing unwanted columns

colums_to_remove = ["SHIPPING_LOCATION", "DEPARTMENT", "PRODUCT_SIZE", "PRICE_RETAIL", "SUBCATEGORY", "BREADCRUMBS", "SKU", "PRODUCT_URL", "PROMOTION", "RunDate", "tid"]

df = df.drop(columns=colums_to_remove)

# %%
df
# Out:
#          index               CATEGORY  \
# 0            0  Hummus, Dips, & Salsa
# 1            1  Hummus, Dips, & Salsa
# 2            2  Hummus, Dips, & Salsa
# 3            3  Hummus, Dips, & Salsa
# 4            4  Hummus, Dips, & Salsa
# ...        ...                    ...
# 568529  568529                   Wine
# 568530  568530                   Wine
# 568531  568531                   Wine
# 568532  568532                   Wine
# 568533  568533                   Wine
#
#                                        PRODUCT_NAME                    BRAND  \
# 0       Marketside Roasted Red Pepper Hummus, 10 Oz               Marketside
# 1           Marketside Roasted Garlic Hummus, 10 Oz               Marketside
# 2                  Marketside Classic Hummus, 10 Oz               Marketside
# 3               Marketside Everything Hummus, 10 oz               Marketside
# 4                      Price's Jalapeno Dip, 12 Oz.                  Price's
# ...                                             ...                      ...
# 568529           Farm Fresh Blueberry Moscato 750ml  Farm Fresh Wine Company
# 568530              Farm Fresh Peach Moscato 750 Ml  Farm Fresh Wine Company
# 568531           Farm Fresh Raspberry Moscato 750ml  Farm Fresh Wine Company
# 568532               Farm Fresh Mango Moscato 750ml  Farm Fresh Wine Company
# 568533          Ole Orleans Heritage Riesling 750ml              Ole Orleans
#
#         PRICE_CURRENT
# 0                2.67
# 1                2.67
# 2                2.67
# 3                2.67
# 4                3.12
# ...               ...
# 568529           9.98
# 568530           9.98
# 568531           9.98
# 568532           9.98
# 568533          18.98
#
# [568534 rows x 5 columns]

# %%
# remove brand name from the product name
def remove_brand_name(product_name, brand_name):
    if pd.notna(brand_name) and brand_name in product_name:
        product_name = product_name.replace(brand_name, '').strip()
        
    # remove everything after the comma
    comma = product_name.find(',')
    if comma != -1:
        product_name = product_name[:comma].strip()
    
    return product_name

df['PRODUCT_NAME'] = df.apply(lambda row: remove_brand_name(row['PRODUCT_NAME'], row['BRAND']), axis=1)

df
# Out:
#          index               CATEGORY                        PRODUCT_NAME  \
# 0            0  Hummus, Dips, & Salsa           Roasted Red Pepper Hummus
# 1            1  Hummus, Dips, & Salsa               Roasted Garlic Hummus
# 2            2  Hummus, Dips, & Salsa                      Classic Hummus
# 3            3  Hummus, Dips, & Salsa                   Everything Hummus
# 4            4  Hummus, Dips, & Salsa                        Jalapeno Dip
# ...        ...                    ...                                 ...
# 568529  568529                   Wine  Farm Fresh Blueberry Moscato 750ml
# 568530  568530                   Wine     Farm Fresh Peach Moscato 750 Ml
# 568531  568531                   Wine  Farm Fresh Raspberry Moscato 750ml
# 568532  568532                   Wine      Farm Fresh Mango Moscato 750ml
# 568533  568533                   Wine             Heritage Riesling 750ml
#
#                           BRAND  PRICE_CURRENT
# 0                    Marketside           2.67
# 1                    Marketside           2.67
# 2                    Marketside           2.67
# 3                    Marketside           2.67
# 4                       Price's           3.12
# ...                         ...            ...
# 568529  Farm Fresh Wine Company           9.98
# 568530  Farm Fresh Wine Company           9.98
# 568531  Farm Fresh Wine Company           9.98
# 568532  Farm Fresh Wine Company           9.98
# 568533              Ole Orleans          18.98
#
# [568534 rows x 5 columns]

# %%
# changing column order
df = df[['index', 'PRODUCT_NAME', 'BRAND', 'CATEGORY', 'PRICE_CURRENT']]
cols = list(df.columns.values)
print(cols)
# Out:
# ['index', 'PRODUCT_NAME', 'BRAND', 'CATEGORY', 'PRICE_CURRENT']

# %%
#skip every 2nd line
df = df.iloc[::5]

df
# Out:
#          index                                       PRODUCT_NAME  \
# 0            0                          Roasted Red Pepper Hummus
# 5            5                                    Green Chili Dip
# 10          10                                       Spicy Hummus
# 15          15                         Honey Jalapeno Hummus 10oz
# 20          20                          Original Queso Cheese Dip
# ...        ...                                                ...
# 568510  568510                          Primos Amore Moscato Wine
# 568515  568515  Winemaker's Selection Chardonnay White Wine 750ml
# 568520  568520                       Collection Pinot Grigio Wine
# 568525  568525            Josh Cellars Reserve Buttery Chardonnay
# 568530  568530                    Farm Fresh Peach Moscato 750 Ml
#
#                           BRAND               CATEGORY  PRICE_CURRENT
# 0                    Marketside  Hummus, Dips, & Salsa           2.67
# 5                       Price's  Hummus, Dips, & Salsa           3.12
# 10                   Marketside  Hummus, Dips, & Salsa           2.67
# 15               Fresh Cravings  Hummus, Dips, & Salsa           3.27
# 20                      Gordo's  Hummus, Dips, & Salsa           5.20
# ...                         ...                    ...            ...
# 568510                    Zonin                   Wine          13.48
# 568515     Winemakers Selection                   Wine          14.98
# 568520                    Cavit                   Wine           8.98
# 568525     JOSH CELLARS RESERVE                   Wine          16.98
# 568530  Farm Fresh Wine Company                   Wine           9.98
#
# [113707 rows x 5 columns]

# %%
# Download the filtered dataset
df.to_csv('./walmart_products.csv', index=False)
